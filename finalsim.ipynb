# %% [markdown]
# <a href="https://colab.research.google.com/github/Shabbarsyed/Cash-Ratio-Analysis/blob/main/finalsim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %%
from google.cloud import bigquery

# %%
from pandas.io import gbq

# %%
df=gbq.read_gbq("select * FROM similaritycheck.urls ",project_id="sustained-works-329217")

# %%
# !pip install boto3
# Out:
# Collecting boto3
#   Downloading boto3-1.28.26-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 3.3 MB/s eta 0:00:00
# Collecting botocore<1.32.0,>=1.31.26 (from boto3)
#   Downloading botocore-1.31.26-py3-none-any.whl (11.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 34.5 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.7.0,>=0.6.0 (from boto3)
#   Downloading s3transfer-0.6.1-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from botocore<1.32.0,>=1.31.26->boto3) (2.8.2)
# Collecting urllib3<1.27,>=1.25.4 (from botocore<1.32.0,>=1.31.26->boto3)
#   Downloading urllib3-1.26.16-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.1/143.1 kB 14.3 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.32.0,>=1.31.26->boto3) (1.16.0)
# Installing collected packages: urllib3, jmespath, botocore, s3transfer, boto3
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.4
#     Uninstalling urllib3-2.0.4:
#       Successfully uninstalled urllib3-2.0.4
# Successfully installed boto3-1.28.26 botocore-1.31.26 jmespath-1.0.1 s3transfer-0.6.1 urllib3-1.26.16

# %%
#importing all libraries
import pandas as pd
import time
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from difflib import SequenceMatcher
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import boto3
import os

# %%
s3 = boto3.client('s3')
s3 = boto3.resource(
    service_name='s3',
    region_name='eu-north-1',
    aws_access_key_id='AKIAWJK4UCNDA6ICEGQO',
    aws_secret_access_key='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'
)

# %%
# Print out bucket names
for bucket in s3.buckets.all():
    print(bucket.name)
# Out:
# newsim-1
# newsim-2
# simcheck

# %%
os.environ["AWS_DEFAULT_REGION"] = 'eu-north-1'
os.environ["AWS_ACCESS_KEY_ID"] = 'AKIAWJK4UCNDA6ICEGQO'
os.environ["AWS_SECRET_ACCESS_KEY"] = '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'

# %%
# Removing Unnecessary Data Column
# Removing Unnecessary Data Column
df= df.iloc[:, [1,6,8,9]]

# %%
df
# Out:
#                                                   Url2  \
# 0    https://www.bettycrocker.co.uk/recipes/celebra...
# 1     https://www.bettycrocker.co.uk/recipes/halloween
# 2    https://www.bettycrocker.co.uk/recipes/brownie...
# 3     https://www.bettycrocker.co.uk/recipes/chocolate
# 4    https://www.bettycrocker.co.uk/how-to/how-to-b...
# ..                                                 ...
# 495          https://ratiofood.com/collections/granola
# 496           https://ratiofood.com/collections/cereal
# 497    https://ratiofood.com/collections/variety-packs
# 498            https://ratiofood.com/pages/about-ratio
# 499  https://ratiofood.com/pages/find-your-ratio-ma...
#
#                                               Url2text  \
# 0    betty's best new years recipes bake in the new...
# 1    celebrate halloween with betty! bake some spoo...
# 2    raspberry & white chocolate fudge brownies try...
# 3    chocolate peanut butter roll this chocolate pe...
# 4    betty's baking tip: how to bake a birthday cak...
# ..                                                 ...
# 495                                               None
# 496                                               None
# 497                                               None
# 498                                               None
# 499                                               None
#
#                   inserted_at                updated_at
# 0   2023-07-05 11:40:28+00:00 2023-07-05 11:40:28+00:00
# 1   2023-07-05 11:40:28+00:00 2023-07-05 11:40:28+00:00
# 2   2023-07-05 11:40:28+00:00 2023-07-05 11:40:28+00:00
# 3   2023-07-05 11:40:28+00:00 2023-07-05 11:40:28+00:00
# 4   2023-07-05 11:40:28+00:00 2023-07-05 11:40:28+00:00
# ..                        ...                       ...
# 495 2023-07-05 11:49:03+00:00 2023-07-05 11:49:03+00:00
# 496 2023-07-05 11:49:03+00:00 2023-07-05 11:49:03+00:00
# 497 2023-07-05 11:49:03+00:00 2023-07-05 11:49:03+00:00
# 498 2023-07-05 11:49:03+00:00 2023-07-05 11:49:03+00:00
# 499 2023-07-05 11:49:03+00:00 2023-07-05 11:49:03+00:00
#
# [500 rows x 4 columns]

# %%
# Chaning Column name TO Url2 To follow the pattern of ALgorithum we have created
df.rename(columns={"ems_page_url": "Url2"}, inplace=True)
df.rename(columns={"text": "Url2text"}, inplace=True)

# %%
# Now removing the unecessary text from url so we can configure that we are not
# comparing the same url
for i in range(len(df)):
    df.loc[i,'Url'] = df.loc[i,'Url2'].replace("https://", "")

# %%
for i in range(len(df)):
    df['Content'] = df['Url'].apply(lambda url: url.split('/', 1)[0])

# %%
# User input here
Url1="https://www.bettycrocker.co.uk"
Url2=Url1.replace("https://", "")

Mainurl=df[df['Content'] == Url2 ]
# removing all the urls that are related to the Urls user enter
df = df[df['Content'] != Url2 ]

# %%
# reseting the indexes
df = df.reset_index(drop=True)

# reseting the indexes
Mainurl= Mainurl.reset_index(drop=True)

# %%
import re

def remove_special_characters_keep_spaces(input_string):
    return re.sub('[^A-Za-z0-9\s]+', '', input_string)
# here we have removed all the special character from our main website link that we are going to compare with
# other websites
for i in range(len(Mainurl)):
    input_string= Mainurl.loc[i,'Url2text']
    Mainurl.loc[i,'Url2text'] = remove_special_characters_keep_spaces(input_string)

# %%
df.loc[200,'Url2text']
# Out:
# 'pizza perfection. superbly stuffed. unlock exclusive content with faze clan faze clan & totino’s have teamed up to bring you a mess free way to enjoy your favorite snack! scan the qr code on the back of the faze clan buffalo chicken pizza rolls package to unlock exclusive content. see promotion party with pepperoni after-school snack. early dinner. easy lunch. weekend breakfast? pepperoni party pizza is there to conquer your hunger no matter what time of day it is. when your stomach is empty, there’s only one real way to get the party started. see party pizza snack hacks bored at home and hungry? you need our snack hacks for your own safety. no one wants to taste-test your last-minute boring ham and cheese sandwich, not even you. amp up our delicious pizza rolls and party pizza with these tasty, easy-to-make dips. see recipes our products pepperoni totino’s® pepperoni pizza rolls® turn a classic pizza topping into a tasty poppable bite. triple cheese totino’s® triple cheese pizza rolls® are wrapped in a crispy golden crust. combination the king kong of pizza rolls. sausage and pepperoni pizza rolled in a poppable bite of goodness. all products follow us on instagram'

# %%
for j in range(len(df)):
      input_stringdf= df.loc[j,'Url2text']
      df.loc[j,'Url2text'] = remove_special_characters_keep_spaces(str(input_stringdf))

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

def sentence_similarity(sentence1, sentence2):
    # Tokenize the input sentences into words
    words1 = word_tokenize(sentence1)
    words2 = word_tokenize(sentence2)

    # Get a set of stopwords
    stop_words = set(stopwords.words('english'))

    # Remove stopwords from the word lists
    words1 = [word for word in words1 if word.lower() not in stop_words]
    words2 = [word for word in words2 if word.lower() not in stop_words]

    # Create a set of unique words from both sentences
    unique_words = set(words1 + words2)

    # Encode the sentences into binary vectors
    vector1 = [1 if word in words1 else 0 for word in unique_words]
    vector2 = [1 if word in words2 else 0 for word in unique_words]

    # Calculate the cosine similarity between the binary vectors
    dot_product = sum(x * y for x, y in zip(vector1, vector2))
    magnitude1 = sum(x ** 2 for x in vector1) ** 0.5
    magnitude2 = sum(x ** 2 for x in vector2) ** 0.5

    cosine_similarity = dot_product / (magnitude1 * magnitude2)

    return cosine_similarity

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
Mainurl
# Out:
#                                                   Url2  \
# 0    https://www.bettycrocker.co.uk/recipes/celebra...
# 1     https://www.bettycrocker.co.uk/recipes/halloween
# 2    https://www.bettycrocker.co.uk/recipes/brownie...
# 3     https://www.bettycrocker.co.uk/recipes/chocolate
# 4    https://www.bettycrocker.co.uk/how-to/how-to-b...
# ..                                                 ...
# 179  https://www.bettycrocker.co.uk/recipes/gingerb...
# 180  https://www.bettycrocker.co.uk/recipes/ombre-cake
# 181  https://www.bettycrocker.co.uk/recipes/valenti...
# 182       https://www.bettycrocker.co.uk/recipes/cakes
# 183    https://www.bettycrocker.co.uk/recipes/birthday
#
#                                               Url2text  \
# 0    bettys best new years recipes bake in the new ...
# 1    celebrate halloween with betty bake some spook...
# 2    raspberry  white chocolate fudge brownies try ...
# 3    chocolate peanut butter roll this chocolate pe...
# 4    bettys baking tip how to bake a birthday cake ...
# ..                                                 ...
# 179  gingerbread and chocolate hazelnut cookies mag...
# 180  ombr cake this blue ombr cake recipe is perfec...
# 181  valentine parfait cupcakes these moist chocola...
# 182  piata surprise cake our fun chocolate piata ca...
# 183  bettys best birthday recipes bake up some fun ...
#
#                   inserted_at                updated_at  \
# 0   2023-07-05 11:40:28+00:00 2023-07-05 11:40:28+00:00
# 1   2023-07-05 11:40:28+00:00 2023-07-05 11:40:28+00:00
# 2   2023-07-05 11:40:28+00:00 2023-07-05 11:40:28+00:00
# 3   2023-07-05 11:40:28+00:00 2023-07-05 11:40:28+00:00
# 4   2023-07-05 11:40:28+00:00 2023-07-05 11:40:28+00:00
# ..                        ...                       ...
# 179 2023-07-06 18:11:27+00:00 2023-07-06 18:11:27+00:00
# 180 2023-07-06 18:11:27+00:00 2023-07-06 18:11:27+00:00
# 181 2023-07-06 18:11:27+00:00 2023-07-06 18:11:27+00:00
# 182 2023-07-05 11:40:27+00:00 2023-07-05 11:40:27+00:00
# 183 2023-07-05 11:40:27+00:00 2023-07-05 11:40:27+00:00
#
#                                                    Url                 Content
# 0          www.bettycrocker.co.uk/recipes/celebrations  www.bettycrocker.co.uk
# 1             www.bettycrocker.co.uk/recipes/halloween  www.bettycrocker.co.uk
# 2     www.bettycrocker.co.uk/recipes/brownies-and-bars  www.bettycrocker.co.uk
# 3             www.bettycrocker.co.uk/recipes/chocolate  www.bettycrocker.co.uk
# 4    www.bettycrocker.co.uk/how-to/how-to-bake-the-...  www.bettycrocker.co.uk
# ..                                                 ...                     ...
# 179  www.bettycrocker.co.uk/recipes/gingerbread-and...  www.bettycrocker.co.uk
# 180          www.bettycrocker.co.uk/recipes/ombre-cake  www.bettycrocker.co.uk
# 181  www.bettycrocker.co.uk/recipes/valentine-parfa...  www.bettycrocker.co.uk
# 182               www.bettycrocker.co.uk/recipes/cakes  www.bettycrocker.co.uk
# 183            www.bettycrocker.co.uk/recipes/birthday  www.bettycrocker.co.uk
#
# [184 rows x 6 columns]

# %%
df
# Out:
#                                                   Url2  \
# 0    https://www.jusrol.co.uk/inspiration/easy-brea...
# 1      https://www.oldelpaso.co.uk/recipes/quesadillas
# 2         https://www.oldelpaso.co.uk/recipes/burritos
# 3            https://www.oldelpaso.co.uk/recipes/tacos
# 4       https://www.oldelpaso.co.uk/recipes/enchiladas
# ..                                                 ...
# 311          https://ratiofood.com/collections/granola
# 312           https://ratiofood.com/collections/cereal
# 313    https://ratiofood.com/collections/variety-packs
# 314            https://ratiofood.com/pages/about-ratio
# 315  https://ratiofood.com/pages/find-your-ratio-ma...
#
#                                               Url2text  \
# 0    easy breakfast ideas breakfast pastries 22nd o...
# 1    quesadilla recipes literally translated as lit...
# 2    burrito recipes seriously satisfying the burri...
# 3    tacos recipes a taco is a traditional mexican ...
# 4    enchilada recipes one of the few mexican dishe...
# ..                                                 ...
# 311                                               None
# 312                                               None
# 313                                               None
# 314                                               None
# 315                                               None
#
#                   inserted_at                updated_at  \
# 0   2023-07-05 11:40:28+00:00 2023-07-05 11:40:28+00:00
# 1   2023-07-05 11:40:40+00:00 2023-07-05 11:40:40+00:00
# 2   2023-07-05 11:40:40+00:00 2023-07-05 11:40:40+00:00
# 3   2023-07-05 11:40:40+00:00 2023-07-05 11:40:40+00:00
# 4   2023-07-05 11:40:40+00:00 2023-07-05 11:40:40+00:00
# ..                        ...                       ...
# 311 2023-07-05 11:49:03+00:00 2023-07-05 11:49:03+00:00
# 312 2023-07-05 11:49:03+00:00 2023-07-05 11:49:03+00:00
# 313 2023-07-05 11:49:03+00:00 2023-07-05 11:49:03+00:00
# 314 2023-07-05 11:49:03+00:00 2023-07-05 11:49:03+00:00
# 315 2023-07-05 11:49:03+00:00 2023-07-05 11:49:03+00:00
#
#                                                    Url              Content
# 0    www.jusrol.co.uk/inspiration/easy-breakfast-ideas     www.jusrol.co.uk
# 1              www.oldelpaso.co.uk/recipes/quesadillas  www.oldelpaso.co.uk
# 2                 www.oldelpaso.co.uk/recipes/burritos  www.oldelpaso.co.uk
# 3                    www.oldelpaso.co.uk/recipes/tacos  www.oldelpaso.co.uk
# 4               www.oldelpaso.co.uk/recipes/enchiladas  www.oldelpaso.co.uk
# ..                                                 ...                  ...
# 311                  ratiofood.com/collections/granola        ratiofood.com
# 312                   ratiofood.com/collections/cereal        ratiofood.com
# 313            ratiofood.com/collections/variety-packs        ratiofood.com
# 314                    ratiofood.com/pages/about-ratio        ratiofood.com
# 315     ratiofood.com/pages/find-your-ratio-match-quiz        ratiofood.com
#
# [316 rows x 6 columns]

# %%
results1=[]
start_time_overall= time.time()
for i in range(len(Mainurl)):
    Url1text = Mainurl.loc[i, 'Url2text']
    Url1 = Mainurl.loc[i, 'Url2']
    insertat=Mainurl.loc[i, 'inserted_at']
    updatedat=Mainurl.loc[i, 'updated_at']
    for j in range(len(df)):
        Url2text = df.loc[j, 'Url2text']
        Url2 = df.loc[j, 'Url2']
        insertatdf=df.loc[i, 'inserted_at']
        updatedatdf=df.loc[i, 'updated_at']

        start_time = time.time()  # Start measuring time
        similarity1 = sentence_similarity(str(Url1text), str(Url2text))
        end_time = time.time()  # End measuring time
        execution_time1 = end_time - start_time

        result = {
            'Url1': Url1, 'Url1text': Url1text, 'Url2': Url2, 'Url2text': Url2text,'similarity': similarity1, 'time': execution_time1,'TargetedURL_Insertedat': insertat, 'TargetedURL_Updatedat': updatedat,
            'CompetatorURL_Insertedat': insertatdf, 'CompetatorURL_Updatedat': updatedatdf,
        }
        results1.append(result)

end_time_overall = time.time()  # End measuring time
execution_time_overall = end_time_overall - start_time_overall

# %%
execution_time_overall
# Out:
# 485.80901646614075

# %%
import csv

with open('F733token1.csv', 'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(["Url1","Url1text","Url2","Url2text", "Similarity","TimeComplexity","TargetedURL_Insertedat","TargetedURL_Updatedat","CompetatorURL_Insertedat","CompetatorURL_Updatedat"])

    for result in results1:
        try:
            writer.writerow([result["Url1"],result['Url1text'],result["Url2"], result['Url2text'], result['similarity'],result['time'],result['TargetedURL_Insertedat'],result['TargetedURL_Updatedat'],result['CompetatorURL_Insertedat'],result['CompetatorURL_Updatedat']])
        except UnicodeEncodeError:
            print(f"Skipping row with Url1text: {result['Url1text']} and Url2text: {result['Url2text']}")
